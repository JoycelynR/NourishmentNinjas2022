# %%
# imports
from tkinter import *
from PIL import ImageTk,Image
import csv
import pandas as pd
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,NavigationToolbar2Tk)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Data Frames
df1 = pd.read_csv('C:/Users/lenas/Downloads/NC_FoodSecurity_County.Child.csv', low_memory=False)
df1['2019-VLFS'] = df1['2019 VLFS #'].str.replace(',', '').astype(int)
df3 = pd.read_csv('C:/Users/lenas/Downloads/NC_2021.2019_Data.csv', low_memory=False)
df3['2019-VLFS'] = df1['2019 Child VLFS #'].str.replace(',', '').astype(int)

#df1 = pd.read_csv('NC_FoodSecurity_County.Child.csv', low_memory=False)
#df2 = pd.read_csv('NC_2021.2019_Data.csv', low_memory=False)
#df3 = pd.read_csv('NC_FoodSource_Data2.csv', low_memory=False)

#Initializing
root = Tk()
root.title('Nourishment Ninjas')

#Functions
def open():
    # window2 = Toplevel(root)
    # window2.title("new window")
    # lbl = Label(window2, text="this is new window")
    # lbl.pack()
    pass

#def show():
    # myLabel = Label(root, text=clicked.get()).pack()
    pass

def move():
    window1 = Toplevel(root)
    window1.title("Food Insecurity")
    lbl1 = Label(window1, text="The U.S. Department of Agriculture (USDA) defines food insecurity as a lack of consistent "
                 "access to enough food for an active, healthy life.\n It is important to know that though "
                 "hunger and food insecurity are closely related, they are distinct concepts.\n Hunger refers to a personal, "
                 "physical sensation of discomfort, while food insecurity refers to a lack of available financial resources "
                 "for food at the household level.")
    lbl1.pack()
    #fig1 = df1["Total Population"].value_counts().hist().get_figure()
   # plot1 = FigureCanvasTkAgg(fig1, window1)
   # plot1.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    
    
   

    #house_prices = np.random.normal(200000,25000,5000)
   # plt.hist(house_prices,50)
   # plt.show()
    
def graph():
    #creating new window
    
     #creating new window
    window2 = Toplevel(root)
    window2.title("County View")
    lbl = Label(window2, text="Food Insecurity by County")
    lbl.pack()
    fig1 = df1.head(10).plot.bar(x=' County', y='2019-VLFS', rot=0,figsize=(10, 10)).get_figure()
    plot1 = FigureCanvasTkAgg(fig1, window2)
    plot1.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    #window2 = Toplevel(root)
    #window2.title("Impact by County")
   # fig1 = df2["# of Food Insecure Persons in 2019"].value_counts().hist().get_figure()
    #df2.head(10).plot.pie(y='2019-VLFS',labels=df[' County'],figsize=(10, 10))#.get_figure()
    #df2.head(10).plot.bar(x=' County', y='2019-VLFS', rot=0,figsize=(10, 10))#.get_figure()
    #fig1 = df.head(10).plot.bar(x=' County', y='2019-VLFS', rot=0,figsize=(10, 10)).get_figure()

    #plot1 = FigureCanvasTkAgg(fig1, window2)

    #plot1.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    #sns.scatterplot(data=data, x='County, State', y='2019 Food Insecurity Rate').get_figure()
    #x,y=np.loadtxt('NC_2021.2019_Data.csv', delimiter=',',unpack=True)
    #plt.plot(x,y,marker='o')
    #plt.title('Impact by County')
    #plt.xlabel('Location')
    #plt.ylabel('Impacted persons')
    #plt.show().get_figure()
   # lbl = Label(window2, text="Affected Counties Across NC")
    #lbl.pack()
    #fig2 = df2["County, State"].value_counts().hist().get_figure()
   # plot2 = FigureCanvasTkAgg(fig2, window2)
   # plot2.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    
def children():
 #creating new window
    window2 = Toplevel(root)
    window2.title("Child Impact")
    lbl = Label(window2, text="Impact on Children by County")
    lbl.pack()
    fig1 = df3.head(10).plot.bar(x='County', y='2019-VLFS', rot=0,figsize=(10, 10)).get_figure()
    plot1 = FigureCanvasTkAgg(fig1, window2)
    plot1.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)

    #window4 = Toplevel(root)
   # window4.title("Child Impact")
   # lbl4 = Label(window4, text="Number of Affected Children in NC, 2019")
   # lbl4.pack()
   # fig4 = df1["Total Population"].value_counts().hist().get_figure()
   # plot4 = FigureCanvasTkAgg(fig4, window4)
   # plot4.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    
def source():
     #creating new window
        
        
        
   
    window3 = Toplevel(root)
    window3.title("Food Sources")
    lbl3 = Label(window3, text="Locations for food in NC")
    lbl3.pack()
    fig3 = df3["Name"].value_counts().hist().get_figure()
    plot3 = FigureCanvasTkAgg(fig3, window3)
    plot3.get_tk_widget().pack(side=TOP, fill=BOTH, expand=1)
    pass


# open screen
frame = LabelFrame(root, text = "WELCOME TO YOUR FOOD INSECURITY RESOURCE", padx=25, pady=25, fg ="white", bg="grey")
frame.pack(padx=25, pady=25)
btn = Button(frame, text= "Nourishment Ninjas",  padx=30, pady=30, fg ="green", bg="black",command=open)
btn.grid(row=1, column=1)
btn.config(font=('Ink Free',20,'bold'))

showBtn = Button(root, text= "What is food insecurity?", command=move).pack()
showBtn = Button(root, text= "Does food insecurity affect one county more than another?",command=graph).pack()
#showBtn = Button(root, text= "How does this impact children?", command=children).pack()
#showBtn = Button(root, text= "Food Sources", command=source).pack()

root.mainloop()
