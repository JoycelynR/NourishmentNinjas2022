# %% [markdown]
# <a href="https://colab.research.google.com/github/Lwilliams121/NourishmentNinjas2022/blob/main/OfficialFinalDataCompare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/DataSet/NC_FoodSource_Data.csv', low_memory=False)

# %%
data = data.drop(["DATE_CREATED","DATE_EDITED"],axis =1)
data.head()
# Out:
#    FEATURE_ID                      Name    Type COUNTY_NAME      City  \
# 0      980026    Academy Heights School  School       Moore  West End
# 1      980028  Acme Delco Middle School  School    Columbus     Delco
# 2      980031        Acorn Ridge Church  Church       Moore   Robbins
# 3      980042        Adams Creek School  School      Craven  Havelock
# 4      980047   Adams Elementary School  School        Wake      Cary
#
#                                           Address
# 0        143 Douglas Ave, West End, NC 27376, USA
# 1  26133 Andrew Jackson Hwy, Delco, NC 28436, USA
# 2      299 Acorn Ridge Rd, Robbins, NC 27325, USA
# 3        101 Belangia Rd, Havelock, NC 28532, USA
# 4        805 Cary Towne Blvd, Cary, NC 27511, USA

# %%
data.columns = data.columns.str.replace(' ','')

# %%
data.groupby('Type').count()[['Address']]
# Out:
#                  Address
# Type
# Building            1166
# Census                82
# Church              3476
# Civil                578
# Hospital              80
# Locale               742
# Populated Place     2626
# Post Office          141
# School              1084

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/DataSet/NC_FoodSecurity_County.Child - NC_FoodSecurity_County.Child.csv', low_memory=False)
data = data.drop(["CD","State","Revised Projections March 2021 VLFS % Change","Revised Projections March 2021\nAdjusted Annual Unemployment Change","Revised Projections March 2021 Child VLFS #","Revised Projections March 2021 Child VLFS % Change","Revised Projections March 2021 Child VLFS # Change"],axis=1)
data.head()
# Out:
#    FIPS Total Population  2019 Very Low Food Security % 2019 VLFS #  \
# 0  3701          763,500                          0.052      39,360
# 1  3702          888,547                          0.044      39,370
# 2  3703          761,753                          0.055      41,540
# 3  3704          873,270                          0.037      32,400
# 4  3705          765,013                          0.058      44,350
#
#    Revised Projections March 2021\nVLFS  %  \
# 0                                    0.057
# 1                                    0.047
# 2                                    0.057
# 3                                    0.042
# 4                                    0.061
#
#   Revised Projections March 2021 VLFS #  \
# 0                                43,280
# 1                                41,720
# 2                                43,410
# 3                                36,880
# 4                                46,400
#
# ...

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/DataSet/NC_2021.2019_Data.csv', encoding='latin-1',low_memory=False)
data = data.drop(["State","Low Threshold in state","Low Threshold Type","High Threshold in state","High Threshold Type","% FI ó Low Threshold","% FI Btwn Thresholds","% FI > High Threshold"],axis =1)
data.head()
# Out:
#     FIPS                     County, State 2019 Food Insecurity Rate  \
# 0  37001   Alamance County, North Carolina                     13.7%
# 1  37003  Alexander County, North Carolina                     14.3%
# 2  37005  Alleghany County, North Carolina                     18.5%
# 3  37007      Anson County, North Carolina                     14.5%
# 4  37009       Ashe County, North Carolina                     15.4%
#
#   # of Food Insecure Persons in 2019 2019 Child food insecurity rate  \
# 0                            22,360                            19.2%
# 1                             5,320                            19.5%
# 2                             2,030                            26.8%
# 3                             3,600                            25.5%
# 4                             4,140                            19.4%
#
#   # of Food Insecure Children in 2019  \
# 0                              7,020
# 1                              1,480
# ...
